# %% [markdown]
# The dataset to be used for the project, Housing Code Violations comes from dataMontgomery.
# This dataset is updated weekly; the last update was June 9, 2019.
#
# Dataset:  Housing Code Violations

# %% [markdown]
# Load Housing Code Violations dataset
#
# Housing Code Enforcement data from 2013 to the present , including violations identified. Update Frequency: Weekly
#
# Source: https://data.montgomerycountymd.gov/Consumer-Housing/Housing-Code-Violations/k9nj-z35d

# %%
#to show where you are
#You need to know where the notebook is located in order to retrieve your downloads.

import os
print(os.getcwd())
# Out:
# C:\Users\GBTC406008ur

# %%
#Import Libraries
import pandas as pd
import numpy as np

# %%
#Load csv file data with headers

location = "downloads/datasets/HousingCodeViolations.csv"
df = pd.read_csv(location)

# %%
#To view the first 5 rows of the dataFrame
df.head()
# Out:
#    Case Number  Date Filed Date Assigned Date Closed              Disposition  \
# 0       155956  2019/05/28    2019/05/28  2019/06/07     Violations Corrected
# 1       155854  2019/05/23    2019/05/23  2019/06/04     Violations Corrected
# 2       155854  2019/05/23    2019/05/23  2019/06/04     Violations Corrected
# 3       155826  2019/05/22    2019/05/22  2019/06/06  FDA - Passed Inspection
# 4       155813  2019/05/21    2019/05/21  2019/05/28      Violation Unfounded
#
#        Street Address Unit Number                City  Zip Code  \
# 0  9847 LAKE SHORE DR         NaN  MONTGOMERY VILLAGE   20886.0
# 1  306 APPLE GROVE RD         NaN       SILVER SPRING   20904.0
# 2  306 APPLE GROVE RD         NaN       SILVER SPRING   20904.0
# 3  12403 BRAXFIELD CT         NaN           ROCKVILLE   20852.0
# 4     19413 LAGUNA DR         NaN        GAITHERSBURG   20879.0
#
#    Service Request Number  ... Latitude Longitude    Location  \
# ...

# %%
df.tail(10)
# Out:
#         Case Number  Date Filed Date Assigned Date Closed  \
# 239330       111049  2013/01/02    2013/01/02  2013/02/12
# 239331       111049  2013/01/02    2013/01/02  2013/02/12
# 239332       111049  2013/01/02    2013/01/02  2013/02/12
# 239333       111039  2013/01/02    2013/01/02  2013/01/08
# 239334       111047  2013/01/02    2013/01/02  2013/03/25
# 239335       111047  2013/01/02    2013/01/02  2013/03/25
# 239336       111040  2013/01/02    2013/01/02  2013/03/07
# 239337       111043  2013/01/02    2013/01/02  2013/02/14
# 239338       111040  2013/01/02    2013/01/02  2013/03/07
# 239339       111043  2013/01/02    2013/01/02  2013/02/14
#
#                  Disposition          Street Address Unit Number  \
# 239330  Violations Corrected        4903 EDGEMOOR LN         NaN
# 239331  Violations Corrected        4903 EDGEMOOR LN         NaN
# 239332  Violations Corrected        4903 EDGEMOOR LN          L7
# ...

# %%
#Show the number of rows and columns in the dataframe
df.shape

#For QA, make sure this matches what is listed on the website as 239K rows and 24 columns.

# %%
#View the column names in the dataset
print(df.columns)

# %%
#Show the data type of each column
df.dtypes

# %%
#descriptive statistics
df.describe()

# %%
df.corr()

# %%
df.shape

# %%
df.ZipCode.count()
